# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from gensim.models import Word2Vec, KeyedVectors
import gensim.downloader as api

# %%
model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
model.most_similar('Earth')
# Out:
# [('planet', 0.7139989733695984),
#  ('earth', 0.7105128169059753),
#  ('Follett_Pillars', 0.5830651521682739),
#  ('planetary', 0.5821980237960815),
#  ('Ian_McShane_Pillars', 0.578964114189148),
#  ('planets', 0.5781013369560242),
#  ('Videsh_Heaven', 0.5705201029777527),
#  ('Mars', 0.5677008032798767),
#  ('cosmos', 0.5637843012809753),
#  ('Red_Planet', 0.5616258978843689)]

# %%
print(model.similarity('Earth', 'Mars'))
print(model.similarity('Earth', 'Man'))
# Out:
# 0.56770074
# 0.16586936

# %%
model.doesnt_match(["DOG","POTATO","RAT"])
# Out:
# 'RAT'

# %%
# ALL
news--> crimial
#skim gram
model = api.load("word2vec-google-news-300")
model["sunny"]
len(model["sunny"])
model["i am sunny"]
model["men"]
model.most_similar("man")
model.most_similar("cricket")
model.similarity("man","woman")
model.similarity("man","python")
model.similarity("man","man")
model.similarity("happy","joy")
model.similarity('python','java')
model.similarity('sunny','sunny')
model.similarity('sunny','Sunny')
model.doesnt_match(["PHP","JAVA","DOG","C++"])
vec=model['king'] - model['man'] + model['woman']
model.most_similar([vec])
## average wrod2vec
sentence = " I love machine learning"

sentece -> vector?

averge Word2Vec

first -> create a vector for each word in the sentence

then -> take the average of all the vectors to get a single vector representation for the entire sentence   
sentence = " I love machine learning"
sentence.lower().split()
words = sentence.lower().split()
word_vectors = []
for word in words:
    print(word)
    word_vectors.append(model[word])
    
word_vectors
import numpy as np
sentence_vector =  np.mean(word_vectors,axis=0)
sentence_vector
sentence_vector.shape
word2vec -> every word into the KeyedVectors

avg word2vec -> every sentence into a vector

now this technique is old, 

will see the sota(transformer based tech in next class)
