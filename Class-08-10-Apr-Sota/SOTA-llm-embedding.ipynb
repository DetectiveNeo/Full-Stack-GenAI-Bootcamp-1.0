# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# 1. HuggingFace Hub(Finetuning Chapter)
# 2. OpenAI SDK(Lang-chain)
# 3. Gemini SDK(Lang-chain)
#
# SDK(Software Development Kit)
#
# - HF
# - Langchain
# - Claude

# %%
from sentence_transformers import SentenceTransformer

# %%
open_source_embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ...

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)
# Out:
# True

# %%
print(bool(os.getenv('HF_KEY')))
print(bool(os.getenv('GOOGLE_API_KEY')))
print(bool(os.getenv('OPENAI_API_KEY')))
# Out:
# True
# True
# True

# %%
text = 'machine'

# %%
embedding = open_source_embedding_model.encode(text)

# %%
len(embedding)
# Out:
# 384

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embedding_model = GoogleGenerativeAIEmbeddings(
    model="models/text-embedding-004",
    google_api_key=os.getenv('GOOGLE_API_KEY')
)

# %%
embeddings = embedding_model.embed_query("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/GitHub_Projects/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/langchain_google_genai/embeddings.py:480, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     479 try:
# --> 480     result = self.client.models.embed_content(
#     481         model=self.model,
#     482         contents=text,
#     483         config=config,
#     484     )
#     485 except ClientError as e:
#
# File ~/GitHub_Projects/Full-Stack-GenAI-Bootcamp-1.0/.venv/lib/python3.12/site-packages/google/genai/models.py:5882, in Models.embed_content(self, model, contents, config)
#    5881 if not self._api_client.vertexai:
# -> 5882   return self._embed_content(model=model, contents=contents, config=config)
#    5884 if t.t_is_vertex_embed_content_model(model):
#
# ...
